# %% [markdown]
# # popPK + Bayesian Forecasting Demo
# ## MIPD Renal Dose Optimizer
#
# This notebook demonstrates population pharmacokinetic modeling with Bayesian forecasting for dose individualization.

# %%
import sys
import os
sys.path.append(os.path.join(os.path.dirname(os.getcwd()), 'src'))

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from src.poppk.bayesian_forecasting import OneCompartmentPKModel, BayesianForecaster
from src.utils import calculate_auc

sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)
