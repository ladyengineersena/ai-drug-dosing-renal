# %% [markdown]
# # ML Hybrid Model Demo
# ## MIPD Renal Dose Optimizer
#
# This notebook demonstrates the hybrid ML + popPK model for dose prediction.

# %%
import sys
import os
sys.path.append(os.path.join(os.path.dirname(os.getcwd()), 'src'))

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from src.models.hybrid import HybridDosePredictor
from src.models.ml_regressor import MLDosePredictor, train_ml_model
from src.poppk.bayesian_forecasting import OneCompartmentPKModel, BayesianForecaster
from src.eval import MIPDEvaluator

sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)
